# %% [markdown]
# # Lab {n}
#
# **Name:** Jack Hatcher
#
# **Due Date:** March 30, 2026

# %% [markdown]
# ## 1. Writing Example
#
# If a lab deliverable asks for writing, place your answer in a markdown field in your report.
#
# If you're not familiar with [markdown](https://www.markdownguide.org/getting-started/), take a few minutes to review the basics.

# %% [markdown]
# ## 2. Image Example
#
# If a lab deliverable asks for an image, hold the shift key and drag the image file into a markdown field to attach the image.
#
# ![turtlebot3_simulation_lidar.png](attachment:turtlebot3_simulation_lidar.png)

# %% [markdown]
# ## 3. Video Example
#
# If a lab deliverable asks for a video, upload the file to YouTube or Google Drive and paste the link in a markdown field.
#
# [Video example](https://www.youtube.com/watch?v=SebvBkGxIFA&list=LL&index=9&t=3s)
#
# Please ensure that the permissions allow for other people to view the video using your link.
# Test this by opening the link in an incognito browser window.
#
# **If the reader/grader cannot access your link by the deadline, the linked section of your assignment will be considered late!**

# %% [markdown]
# ## 4. Code Example
#
# If a lab deliverable asks for code, paste the code into a code block in your report.
#
# The code doesn't need to run properly in the notebook.
#
# The notebook allows for propper code formatting and colors.

# %%
print('Hello TECHIN 517!')
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %% [markdown]
# ## 5. Export to PDF
#
# When you finish your lab report in your Jupyter Notebook, export to PDF.
#
# This might require additional dependencies, check the VS Code output if your export fails.
